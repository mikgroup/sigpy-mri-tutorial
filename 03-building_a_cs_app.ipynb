# %% [markdown]
# In this notebook, you will
# - Learn how to use `Linop`, `Prox`, and `Alg` to create an `App`
# - Create a Fourier compressed sensing `App`
#
# SigPy provides abstractions for linear operator, proximal operator and iterative algorithms. This is similar to how BART abstracts the iterative reconstruction. By dividing functions into these three classes, many components can be reused, and code can be drastically shortened.
#
# ![architecture](https://sigpy.readthedocs.io/en/latest/_images/architecture.pdf)

# %%
# %matplotlib notebook
import numpy as np
import sigpy as sp
import sigpy.mri as mr
import sigpy.plot as pl

# %% [markdown]
# The problem we are interested in solving in this tutorial is the following:
# $$\min_x \frac{1}{2} \| P F x - y \|_2^2 + \lambda \| W x \|_1$$
# where $P$ is the sampling operator, $F$ is the Fourier transform operator, $W$ is the wavelet transform operator, $x$ is the image and $y$ is the acquired k-space measurements.

# %%
ksp = np.load('data/cartesian_ksp.npy')

# %%
ksp /= np.abs(img_adj).max()

# %%
img_shape = ksp.shape[1:]

# %% [markdown]
# # Linop
#
# https://sigpy.readthedocs.io/en/latest/core_linop.html

# %%
F = sp.linop.FFT(ksp.shape, axes=(-1, -2))
img_adj = F.H * ksp # Alternatively can also do F(x)

pl.ImagePlot(img_adj, z=0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mps = mr.app.EspiritCalib(ksp).run()
# Out:
# EspiritCalib:   0%|          | 0/100 [00:00<?, ?it/s]
#
# EspiritCalib:   1%|          | 1/100 [00:00<00:01, 51.02it/s]
#
# EspiritCalib:   2%|▏         | 2/100 [00:00<00:01, 53.00it/s]
#
# EspiritCalib:   3%|▎         | 3/100 [00:00<00:01, 50.75it/s]
#
# EspiritCalib:   4%|▍         | 4/100 [00:00<00:01, 51.49it/s]
#
# EspiritCalib:   5%|▌         | 5/100 [00:00<00:01, 55.19it/s]
#
# EspiritCalib:   6%|▌         | 6/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:   6%|▌         | 6/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:   7%|▋         | 7/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:   8%|▊         | 8/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:   9%|▉         | 9/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:  10%|█         | 10/100 [00:00<00:01, 58.43it/s]
#
# EspiritCalib:  11%|█         | 11/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  11%|█         | 11/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  12%|█▏        | 12/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  13%|█▎        | 13/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  14%|█▍        | 14/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  15%|█▌        | 15/100 [00:00<00:01, 55.38it/s]
#
# EspiritCalib:  16%|█▌        | 16/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  16%|█▌        | 16/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  17%|█▋        | 17/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  18%|█▊        | 18/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  19%|█▉        | 19/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  20%|██        | 20/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  21%|██        | 21/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  22%|██▏       | 22/100 [00:00<00:01, 53.62it/s]
#
# EspiritCalib:  23%|██▎       | 23/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  23%|██▎       | 23/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  24%|██▍       | 24/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  25%|██▌       | 25/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  26%|██▌       | 26/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  27%|██▋       | 27/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  28%|██▊       | 28/100 [00:00<00:01, 57.01it/s]
#
# EspiritCalib:  29%|██▉       | 29/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  29%|██▉       | 29/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  30%|███       | 30/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  31%|███       | 31/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  32%|███▏      | 32/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  33%|███▎      | 33/100 [00:00<00:01, 57.65it/s]
#
# EspiritCalib:  34%|███▍      | 34/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  34%|███▍      | 34/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  35%|███▌      | 35/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  36%|███▌      | 36/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  37%|███▋      | 37/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  38%|███▊      | 38/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  39%|███▉      | 39/100 [00:00<00:01, 55.11it/s]
#
# EspiritCalib:  40%|████      | 40/100 [00:00<00:01, 56.22it/s]
#
# EspiritCalib:  40%|████      | 40/100 [00:00<00:01, 56.22it/s]
#
# EspiritCalib:  41%|████      | 41/100 [00:00<00:01, 56.22it/s]
#
# EspiritCalib:  42%|████▏     | 42/100 [00:00<00:01, 56.22it/s]
#
# EspiritCalib:  43%|████▎     | 43/100 [00:00<00:01, 56.22it/s]
#
# EspiritCalib:  44%|████▍     | 44/100 [00:00<00:00, 56.22it/s]
#
# EspiritCalib:  45%|████▌     | 45/100 [00:00<00:00, 56.22it/s]
#
# EspiritCalib:  46%|████▌     | 46/100 [00:00<00:00, 56.22it/s]
#
# EspiritCalib:  47%|████▋     | 47/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  47%|████▋     | 47/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  48%|████▊     | 48/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  49%|████▉     | 49/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  50%|█████     | 50/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  51%|█████     | 51/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  52%|█████▏    | 52/100 [00:00<00:00, 59.47it/s]
#
# EspiritCalib:  53%|█████▎    | 53/100 [00:00<00:00, 55.33it/s]
#
# EspiritCalib:  53%|█████▎    | 53/100 [00:00<00:00, 55.33it/s]
#
# EspiritCalib:  54%|█████▍    | 54/100 [00:00<00:00, 55.33it/s]
#
# EspiritCalib:  55%|█████▌    | 55/100 [00:00<00:00, 55.33it/s]
#
# EspiritCalib:  56%|█████▌    | 56/100 [00:01<00:00, 55.33it/s]
#
# EspiritCalib:  57%|█████▋    | 57/100 [00:01<00:00, 55.33it/s]
#
# EspiritCalib:  58%|█████▊    | 58/100 [00:01<00:00, 55.33it/s]
#
# EspiritCalib:  59%|█████▉    | 59/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  59%|█████▉    | 59/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  60%|██████    | 60/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  61%|██████    | 61/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  62%|██████▏   | 62/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  63%|██████▎   | 63/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  64%|██████▍   | 64/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  65%|██████▌   | 65/100 [00:01<00:00, 55.40it/s]
#
# EspiritCalib:  66%|██████▌   | 66/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  66%|██████▌   | 66/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  67%|██████▋   | 67/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  68%|██████▊   | 68/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  69%|██████▉   | 69/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  70%|███████   | 70/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  71%|███████   | 71/100 [00:01<00:00, 56.51it/s]
#
# EspiritCalib:  72%|███████▏  | 72/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  72%|███████▏  | 72/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  73%|███████▎  | 73/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  74%|███████▍  | 74/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  75%|███████▌  | 75/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  76%|███████▌  | 76/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  77%|███████▋  | 77/100 [00:01<00:00, 54.03it/s]
#
# EspiritCalib:  78%|███████▊  | 78/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  78%|███████▊  | 78/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  79%|███████▉  | 79/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  80%|████████  | 80/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  81%|████████  | 81/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  82%|████████▏ | 82/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  83%|████████▎ | 83/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  84%|████████▍ | 84/100 [00:01<00:00, 55.35it/s]
#
# EspiritCalib:  85%|████████▌ | 85/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  85%|████████▌ | 85/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  86%|████████▌ | 86/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  87%|████████▋ | 87/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  88%|████████▊ | 88/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  89%|████████▉ | 89/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  90%|█████████ | 90/100 [00:01<00:00, 56.98it/s]
#
# EspiritCalib:  91%|█████████ | 91/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  91%|█████████ | 91/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  92%|█████████▏| 92/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  93%|█████████▎| 93/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  94%|█████████▍| 94/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  95%|█████████▌| 95/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  96%|█████████▌| 96/100 [00:01<00:00, 54.89it/s]
#
# EspiritCalib:  97%|█████████▋| 97/100 [00:01<00:00, 53.72it/s]
#
# EspiritCalib:  97%|█████████▋| 97/100 [00:01<00:00, 53.72it/s]
#
# EspiritCalib:  98%|█████████▊| 98/100 [00:01<00:00, 53.72it/s]
#
# EspiritCalib:  99%|█████████▉| 99/100 [00:01<00:00, 53.72it/s]
#
# EspiritCalib: 100%|██████████| 100/100 [00:01<00:00, 53.72it/s]
# EspiritCalib: 100%|██████████| 100/100 [00:01<00:00, 55.20it/s]

# %%
S = sp.linop.Multiply(img_shape, mps)

img_adj = S.H * F.H * ksp

pl.ImagePlot(img_adj)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
mask = np.sum(abs(ksp), axis=0) > 0

pl.ImagePlot(mask)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
P = sp.linop.Multiply(ksp.shape, mask)
A = P * F * S

img_adj = A.H * ksp

pl.ImagePlot(img_adj)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
W = sp.linop.Wavelet(img_shape)
wav = W * img_adj
pl.ImagePlot(wav)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Prox
#
# https://sigpy.readthedocs.io/en/latest/core_prox.html

# %%
lamda = 0.01
proxg = sp.prox.L1Reg(wav.shape, lamda)
alpha = 1
wav_thresh = proxg(alpha, wav)

pl.ImagePlot(wav_thresh)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A = P * F * S * W.H

# %% [markdown]
# # Alg
#
# https://sigpy.readthedocs.io/en/latest/core_alg.html

# %%
max_iter = 100
alpha = 1

def gradf(x):
    return A.H * (A * x - ksp)

wav_hat = np.zeros(wav.shape, np.complex)
alg = sp.alg.GradientMethod(gradf, wav_hat, alpha, proxg=proxg, 
                            max_iter=max_iter)

# %%
while not alg.done():
    alg.update()
    print('\rIteration: {}'.format(alg.iter))
# Out:
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5
# Iteration: 6
# Iteration: 7
# Iteration: 8
# Iteration: 9
# Iteration: 10
# Iteration: 11
# Iteration: 12
# Iteration: 13
# Iteration: 14
# Iteration: 15
# Iteration: 16
# Iteration: 17
# Iteration: 18
# Iteration: 19
# Iteration: 20
# Iteration: 21
# Iteration: 22
# Iteration: 23
# Iteration: 24
# Iteration: 25
# Iteration: 26
# Iteration: 27
# Iteration: 28
# Iteration: 29
# Iteration: 30
# Iteration: 31
# Iteration: 32
# Iteration: 33
# Iteration: 34
# Iteration: 35
# Iteration: 36
# Iteration: 37
# Iteration: 38
# Iteration: 39
# Iteration: 40
# Iteration: 41
# Iteration: 42
# Iteration: 43
# Iteration: 44
# Iteration: 45
# Iteration: 46
# Iteration: 47
# Iteration: 48
# Iteration: 49
# Iteration: 50
# Iteration: 51
# Iteration: 52
# Iteration: 53
# Iteration: 54
# Iteration: 55
# Iteration: 56
# Iteration: 57
# Iteration: 58
# Iteration: 59
# Iteration: 60
# Iteration: 61
# Iteration: 62
# Iteration: 63
# Iteration: 64
# Iteration: 65
# Iteration: 66
# Iteration: 67
# Iteration: 68
# Iteration: 69
# Iteration: 70
# Iteration: 71
# Iteration: 72
# Iteration: 73
# Iteration: 74
# Iteration: 75
# Iteration: 76
# Iteration: 77
# Iteration: 78
# Iteration: 79
# Iteration: 80
# Iteration: 81
# Iteration: 82
# Iteration: 83
# Iteration: 84
# Iteration: 85
# Iteration: 86
# Iteration: 87
# Iteration: 88
# Iteration: 89
# Iteration: 90
# Iteration: 91
# Iteration: 92
# Iteration: 93
# Iteration: 94
# Iteration: 95
# Iteration: 96
# Iteration: 97
# Iteration: 98
# Iteration: 99
# Iteration: 100

# %%
pl.ImagePlot(W.H(wav_hat))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # App

# %%
class FourierCompressedSensing(sp.app.App):
    def __init__(self, ksp, mask, mps, lamda, max_iter):
        img_shape = mps.shape[1:]
        
        S = sp.linop.Multiply(img_shape, mps)
        F = sp.linop.FFT(ksp.shape, axes=(-1, -2))
        P = sp.linop.Multiply(ksp.shape, mask)
        self.W = sp.linop.Wavelet(img_shape)
        A = P * F * S * self.W.H
        
        proxg = sp.prox.L1Reg(A.ishape, lamda)
        
        self.wav = np.zeros(A.ishape, np.complex)
        alpha = 1
        alg = sp.alg.GradientMethod(lambda x: A.H * (A * x - ksp), self.wav, alpha, proxg=proxg, 
                                    max_iter=max_iter)
        super().__init__(alg)
        
    def _output(self):
        return self.W.H(self.wav)

# %%
x_hat = FourierCompressedSensing(ksp, mask, mps, lamda, max_iter).run()
# Out:
# FourierCompressedSensing:   0%|          | 0/100 [00:00<?, ?it/s]
#
#
# FourierCompressedSensing:   1%|          | 1/100 [00:00<00:07, 12.78it/s]
#
#
# FourierCompressedSensing:   2%|▏         | 2/100 [00:00<00:09, 10.14it/s]
#
#
# FourierCompressedSensing:   2%|▏         | 2/100 [00:00<00:09, 10.14it/s]
#
#
# FourierCompressedSensing:   3%|▎         | 3/100 [00:00<00:09, 10.02it/s]
#
#
# FourierCompressedSensing:   3%|▎         | 3/100 [00:00<00:09, 10.02it/s]
#
#
# FourierCompressedSensing:   4%|▍         | 4/100 [00:00<00:10,  9.55it/s]
#
#
# FourierCompressedSensing:   4%|▍         | 4/100 [00:00<00:10,  9.55it/s]
#
#
# FourierCompressedSensing:   5%|▌         | 5/100 [00:00<00:11,  8.56it/s]
#
#
# FourierCompressedSensing:   5%|▌         | 5/100 [00:00<00:11,  8.56it/s]
#
#
# FourierCompressedSensing:   6%|▌         | 6/100 [00:00<00:11,  7.98it/s]
#
#
# FourierCompressedSensing:   6%|▌         | 6/100 [00:00<00:11,  7.98it/s]
#
#
# FourierCompressedSensing:   7%|▋         | 7/100 [00:00<00:11,  8.17it/s]
#
#
# FourierCompressedSensing:   7%|▋         | 7/100 [00:00<00:11,  8.17it/s]
#
#
# FourierCompressedSensing:   8%|▊         | 8/100 [00:00<00:11,  8.17it/s]
#
#
# FourierCompressedSensing:   9%|▉         | 9/100 [00:00<00:09,  9.68it/s]
#
#
# FourierCompressedSensing:   9%|▉         | 9/100 [00:00<00:09,  9.68it/s]
#
#
# FourierCompressedSensing:  10%|█         | 10/100 [00:00<00:09,  9.68it/s]
#
#
# FourierCompressedSensing:  11%|█         | 11/100 [00:01<00:07, 11.30it/s]
#
#
# FourierCompressedSensing:  11%|█         | 11/100 [00:01<00:07, 11.30it/s]
#
#
# FourierCompressedSensing:  12%|█▏        | 12/100 [00:01<00:07, 11.30it/s]
#
#
# FourierCompressedSensing:  13%|█▎        | 13/100 [00:01<00:06, 12.96it/s]
#
#
# FourierCompressedSensing:  13%|█▎        | 13/100 [00:01<00:06, 12.96it/s]
#
#
# FourierCompressedSensing:  14%|█▍        | 14/100 [00:01<00:06, 12.96it/s]
#
#
# FourierCompressedSensing:  15%|█▌        | 15/100 [00:01<00:06, 12.96it/s]
#
#
# FourierCompressedSensing:  16%|█▌        | 16/100 [00:01<00:05, 14.58it/s]
#
#
# FourierCompressedSensing:  16%|█▌        | 16/100 [00:01<00:05, 14.58it/s]
#
#
# FourierCompressedSensing:  17%|█▋        | 17/100 [00:01<00:05, 14.58it/s]
#
#
# FourierCompressedSensing:  18%|█▊        | 18/100 [00:01<00:05, 14.58it/s]
#
#
# FourierCompressedSensing:  19%|█▉        | 19/100 [00:01<00:05, 15.94it/s]
#
#
# FourierCompressedSensing:  19%|█▉        | 19/100 [00:01<00:05, 15.94it/s]
#
#
# FourierCompressedSensing:  20%|██        | 20/100 [00:01<00:05, 15.94it/s]
#
#
# FourierCompressedSensing:  21%|██        | 21/100 [00:01<00:05, 15.69it/s]
#
#
# FourierCompressedSensing:  21%|██        | 21/100 [00:01<00:05, 15.69it/s]
#
#
# FourierCompressedSensing:  22%|██▏       | 22/100 [00:01<00:04, 15.69it/s]
#
#
# FourierCompressedSensing:  23%|██▎       | 23/100 [00:01<00:04, 16.16it/s]
#
#
# FourierCompressedSensing:  23%|██▎       | 23/100 [00:01<00:04, 16.16it/s]
#
#
# FourierCompressedSensing:  24%|██▍       | 24/100 [00:01<00:04, 16.16it/s]
#
#
# FourierCompressedSensing:  25%|██▌       | 25/100 [00:01<00:04, 16.19it/s]
#
#
# FourierCompressedSensing:  25%|██▌       | 25/100 [00:01<00:04, 16.19it/s]
#
#
# FourierCompressedSensing:  26%|██▌       | 26/100 [00:01<00:04, 16.19it/s]
#
#
# FourierCompressedSensing:  27%|██▋       | 27/100 [00:01<00:04, 16.15it/s]
#
#
# FourierCompressedSensing:  27%|██▋       | 27/100 [00:01<00:04, 16.15it/s]
#
#
# FourierCompressedSensing:  28%|██▊       | 28/100 [00:01<00:04, 16.15it/s]
#
#
# FourierCompressedSensing:  29%|██▉       | 29/100 [00:02<00:04, 16.77it/s]
#
#
# FourierCompressedSensing:  29%|██▉       | 29/100 [00:02<00:04, 16.77it/s]
#
#
# FourierCompressedSensing:  30%|███       | 30/100 [00:02<00:04, 16.77it/s]
#
#
# FourierCompressedSensing:  31%|███       | 31/100 [00:02<00:04, 15.94it/s]
#
#
# FourierCompressedSensing:  31%|███       | 31/100 [00:02<00:04, 15.94it/s]
#
#
# FourierCompressedSensing:  32%|███▏      | 32/100 [00:02<00:04, 15.94it/s]
#
#
# FourierCompressedSensing:  33%|███▎      | 33/100 [00:02<00:04, 16.30it/s]
#
#
# FourierCompressedSensing:  33%|███▎      | 33/100 [00:02<00:04, 16.30it/s]
#
#
# FourierCompressedSensing:  34%|███▍      | 34/100 [00:02<00:04, 16.30it/s]
#
#
# FourierCompressedSensing:  35%|███▌      | 35/100 [00:02<00:03, 17.06it/s]
#
#
# FourierCompressedSensing:  35%|███▌      | 35/100 [00:02<00:03, 17.06it/s]
#
#
# FourierCompressedSensing:  36%|███▌      | 36/100 [00:02<00:03, 17.06it/s]
#
#
# FourierCompressedSensing:  37%|███▋      | 37/100 [00:02<00:03, 16.45it/s]
#
#
# FourierCompressedSensing:  37%|███▋      | 37/100 [00:02<00:03, 16.45it/s]
#
#
# FourierCompressedSensing:  38%|███▊      | 38/100 [00:02<00:03, 16.45it/s]
#
#
# FourierCompressedSensing:  39%|███▉      | 39/100 [00:02<00:03, 16.51it/s]
#
#
# FourierCompressedSensing:  39%|███▉      | 39/100 [00:02<00:03, 16.51it/s]
#
#
# FourierCompressedSensing:  40%|████      | 40/100 [00:02<00:03, 16.51it/s]
#
#
# FourierCompressedSensing:  41%|████      | 41/100 [00:02<00:03, 16.51it/s]
#
#
# FourierCompressedSensing:  42%|████▏     | 42/100 [00:02<00:03, 16.99it/s]
#
#
# FourierCompressedSensing:  42%|████▏     | 42/100 [00:02<00:03, 16.99it/s]
#
#
# FourierCompressedSensing:  43%|████▎     | 43/100 [00:02<00:03, 16.99it/s]
#
#
# FourierCompressedSensing:  44%|████▍     | 44/100 [00:02<00:03, 16.79it/s]
#
#
# FourierCompressedSensing:  44%|████▍     | 44/100 [00:02<00:03, 16.79it/s]
#
#
# FourierCompressedSensing:  45%|████▌     | 45/100 [00:03<00:03, 16.79it/s]
#
#
# FourierCompressedSensing:  46%|████▌     | 46/100 [00:03<00:03, 17.37it/s]
#
#
# FourierCompressedSensing:  46%|████▌     | 46/100 [00:03<00:03, 17.37it/s]
#
#
# FourierCompressedSensing:  47%|████▋     | 47/100 [00:03<00:03, 17.37it/s]
#
#
# FourierCompressedSensing:  48%|████▊     | 48/100 [00:03<00:02, 18.01it/s]
#
#
# FourierCompressedSensing:  48%|████▊     | 48/100 [00:03<00:02, 18.01it/s]
#
#
# FourierCompressedSensing:  49%|████▉     | 49/100 [00:03<00:02, 18.01it/s]
#
#
# FourierCompressedSensing:  50%|█████     | 50/100 [00:03<00:02, 16.92it/s]
#
#
# FourierCompressedSensing:  50%|█████     | 50/100 [00:03<00:02, 16.92it/s]
#
#
# FourierCompressedSensing:  51%|█████     | 51/100 [00:03<00:02, 16.92it/s]
#
#
# FourierCompressedSensing:  52%|█████▏    | 52/100 [00:03<00:02, 17.04it/s]
#
#
# FourierCompressedSensing:  52%|█████▏    | 52/100 [00:03<00:02, 17.04it/s]
#
#
# FourierCompressedSensing:  53%|█████▎    | 53/100 [00:03<00:02, 17.04it/s]
#
#
# FourierCompressedSensing:  54%|█████▍    | 54/100 [00:03<00:02, 17.22it/s]
#
#
# FourierCompressedSensing:  54%|█████▍    | 54/100 [00:03<00:02, 17.22it/s]
#
#
# FourierCompressedSensing:  55%|█████▌    | 55/100 [00:03<00:02, 17.22it/s]
#
#
# FourierCompressedSensing:  56%|█████▌    | 56/100 [00:03<00:02, 17.07it/s]
#
#
# FourierCompressedSensing:  56%|█████▌    | 56/100 [00:03<00:02, 17.07it/s]
#
#
# FourierCompressedSensing:  57%|█████▋    | 57/100 [00:03<00:02, 17.07it/s]
#
#
# FourierCompressedSensing:  58%|█████▊    | 58/100 [00:03<00:02, 16.87it/s]
#
#
# FourierCompressedSensing:  58%|█████▊    | 58/100 [00:03<00:02, 16.87it/s]
#
#
# FourierCompressedSensing:  59%|█████▉    | 59/100 [00:03<00:02, 16.87it/s]
#
#
# FourierCompressedSensing:  60%|██████    | 60/100 [00:03<00:02, 16.90it/s]
#
#
# FourierCompressedSensing:  60%|██████    | 60/100 [00:03<00:02, 16.90it/s]
#
#
# FourierCompressedSensing:  61%|██████    | 61/100 [00:03<00:02, 16.90it/s]
#
#
# FourierCompressedSensing:  62%|██████▏   | 62/100 [00:04<00:02, 15.89it/s]
#
#
# FourierCompressedSensing:  62%|██████▏   | 62/100 [00:04<00:02, 15.89it/s]
# FourierCompressedSensing:  63%|██████▎   | 63/100 [00:04<00:02, 15.89it/s]
#
#
# FourierCompressedSensing:  64%|██████▍   | 64/100 [00:04<00:02, 16.27it/s]
#
#
# FourierCompressedSensing:  64%|██████▍   | 64/100 [00:04<00:02, 16.27it/s]
#
#
# FourierCompressedSensing:  65%|██████▌   | 65/100 [00:04<00:02, 16.27it/s]
#
#
# FourierCompressedSensing:  66%|██████▌   | 66/100 [00:04<00:02, 16.74it/s]
#
#
# FourierCompressedSensing:  66%|██████▌   | 66/100 [00:04<00:02, 16.74it/s]
#
#
# FourierCompressedSensing:  67%|██████▋   | 67/100 [00:04<00:01, 16.74it/s]
#
#
# FourierCompressedSensing:  68%|██████▊   | 68/100 [00:04<00:01, 16.50it/s]
#
#
# FourierCompressedSensing:  68%|██████▊   | 68/100 [00:04<00:01, 16.50it/s]
#
#
# FourierCompressedSensing:  69%|██████▉   | 69/100 [00:04<00:01, 16.50it/s]
#
#
# FourierCompressedSensing:  70%|███████   | 70/100 [00:04<00:01, 16.75it/s]
#
#
# FourierCompressedSensing:  70%|███████   | 70/100 [00:04<00:01, 16.75it/s]
#
#
# FourierCompressedSensing:  71%|███████   | 71/100 [00:04<00:01, 16.75it/s]
#
#
# FourierCompressedSensing:  72%|███████▏  | 72/100 [00:04<00:01, 16.75it/s]
#
#
# FourierCompressedSensing:  73%|███████▎  | 73/100 [00:04<00:01, 17.77it/s]
#
#
# FourierCompressedSensing:  73%|███████▎  | 73/100 [00:04<00:01, 17.77it/s]
#
#
# FourierCompressedSensing:  74%|███████▍  | 74/100 [00:04<00:01, 17.77it/s]
#
#
# FourierCompressedSensing:  75%|███████▌  | 75/100 [00:04<00:01, 17.40it/s]
#
#
# FourierCompressedSensing:  75%|███████▌  | 75/100 [00:04<00:01, 17.40it/s]
#
#
# FourierCompressedSensing:  76%|███████▌  | 76/100 [00:04<00:01, 17.40it/s]
#
#
# FourierCompressedSensing:  77%|███████▋  | 77/100 [00:04<00:01, 17.34it/s]
#
#
# FourierCompressedSensing:  77%|███████▋  | 77/100 [00:04<00:01, 17.34it/s]
#
#
# FourierCompressedSensing:  78%|███████▊  | 78/100 [00:04<00:01, 17.34it/s]
#
#
# FourierCompressedSensing:  79%|███████▉  | 79/100 [00:04<00:01, 17.34it/s]
#
#
# FourierCompressedSensing:  80%|████████  | 80/100 [00:05<00:01, 18.29it/s]
#
#
# FourierCompressedSensing:  80%|████████  | 80/100 [00:05<00:01, 18.29it/s]
#
#
# FourierCompressedSensing:  81%|████████  | 81/100 [00:05<00:01, 18.29it/s]
#
#
# FourierCompressedSensing:  82%|████████▏ | 82/100 [00:05<00:01, 17.46it/s]
#
#
# FourierCompressedSensing:  82%|████████▏ | 82/100 [00:05<00:01, 17.46it/s]
#
#
# FourierCompressedSensing:  83%|████████▎ | 83/100 [00:05<00:00, 17.46it/s]
#
#
# FourierCompressedSensing:  84%|████████▍ | 84/100 [00:05<00:00, 17.49it/s]
#
#
# FourierCompressedSensing:  84%|████████▍ | 84/100 [00:05<00:00, 17.49it/s]
#
#
# FourierCompressedSensing:  85%|████████▌ | 85/100 [00:05<00:00, 17.49it/s]
#
#
# FourierCompressedSensing:  86%|████████▌ | 86/100 [00:05<00:00, 17.49it/s]
#
#
# FourierCompressedSensing:  87%|████████▋ | 87/100 [00:05<00:00, 18.52it/s]
#
#
# FourierCompressedSensing:  87%|████████▋ | 87/100 [00:05<00:00, 18.52it/s]
#
#
# FourierCompressedSensing:  88%|████████▊ | 88/100 [00:05<00:00, 18.52it/s]
#
#
# FourierCompressedSensing:  89%|████████▉ | 89/100 [00:05<00:00, 17.62it/s]
#
#
# FourierCompressedSensing:  89%|████████▉ | 89/100 [00:05<00:00, 17.62it/s]
#
#
# FourierCompressedSensing:  90%|█████████ | 90/100 [00:05<00:00, 17.62it/s]
#
#
# FourierCompressedSensing:  91%|█████████ | 91/100 [00:05<00:00, 17.66it/s]
#
#
# FourierCompressedSensing:  91%|█████████ | 91/100 [00:05<00:00, 17.66it/s]
#
#
# FourierCompressedSensing:  92%|█████████▏| 92/100 [00:05<00:00, 17.66it/s]
#
#
# FourierCompressedSensing:  93%|█████████▎| 93/100 [00:05<00:00, 17.66it/s]
#
#
# FourierCompressedSensing:  94%|█████████▍| 94/100 [00:05<00:00, 18.78it/s]
#
#
# FourierCompressedSensing:  94%|█████████▍| 94/100 [00:05<00:00, 18.78it/s]
#
#
# FourierCompressedSensing:  95%|█████████▌| 95/100 [00:05<00:00, 18.78it/s]
#
#
# FourierCompressedSensing:  96%|█████████▌| 96/100 [00:05<00:00, 17.63it/s]
#
#
# FourierCompressedSensing:  96%|█████████▌| 96/100 [00:05<00:00, 17.63it/s]
#
#
# FourierCompressedSensing:  97%|█████████▋| 97/100 [00:05<00:00, 17.63it/s]
#
#
# FourierCompressedSensing:  98%|█████████▊| 98/100 [00:06<00:00, 17.78it/s]
#
#
# FourierCompressedSensing:  98%|█████████▊| 98/100 [00:06<00:00, 17.78it/s]
#
#
# FourierCompressedSensing:  99%|█████████▉| 99/100 [00:06<00:00, 17.78it/s]
#
#
# FourierCompressedSensing: 100%|██████████| 100/100 [00:06<00:00, 17.78it/s]
#
#
# FourierCompressedSensing: 100%|██████████| 100/100 [00:06<00:00, 16.38it/s]

# %%
pl.ImagePlot(x_hat)
# Out:
# <img src="data:image/png;base64,..." width="640">
